# %%
import requests
import re

from bs4 import BeautifulSoup

# %% [markdown]
# #### This url is having information about how to build a static websites

# %%
url = "https://www.imdb.com/list/ls000060680/"

resp = requests.get(url)

# %%
soup = BeautifulSoup(resp.text, 'lxml')

soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///list/ls000060680?src=mdot" name="apple-itunes-app"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>My Top 100 Movies of All Time  - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="app-id=342792525, app-argument=imdb:///list/ls000060680?src=mdot" name="apple-itunes-app"/>
#   <script type="text/javascript">
#    var IMDbTimer={starttime: new Date().getTime(),pt:'java'};
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <title>
#    My Top 100 Movies of All Time  - IMDb
#   </title>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
#   </script>
# ...

# %% [markdown]
# ### Extracting a list of links from a web page using BeautifulSoup

# %% [markdown]
# #### In any webpage links are created inside "a" tag, "link" tag and links for images in "img" tag. Any link should starts with https|http, so to extract only links from tags we should give expression to code so here we are using regular expression filter to extract only links fron tags.

# %% [markdown]
# This code will give list of links which are having the attribute("href") value started with "https"(not include "http") in "a" along with complete content of "a" tag.

# %%
for i in soup.find_all("a",  attrs = {'href': re.compile("^http")}):
    print(i['href'])
# Out:
# https://www.imdb.com/calendar/?ref_=nv_mv_cal
# https://www.imdb.com/list/ls016522954/?ref_=nv_tvv_dvd
# https://www.imdb.com/feature/genre/?ref_=nv_ch_gr
# https://m.imdb.com/showtimes/movie/?ref_=nv_mv_sh
# https://www.imdb.com/showtimes/?ref_=nv_mv_sh
# https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth
# https://m.imdb.com/coming-soon/?ref_=nv_mv_cs
# https://www.imdb.com/coming-soon/?ref_=nv_mv_cs
# https://www.imdb.com/whats-on-tv/?ref_=nv_tv_ontv
# https://m.imdb.com/whats-on-tv/?ref_=nv_tv_ontv
# https://www.imdb.com/feature/genre/?ref_=nv_tv_gr
# https://m.imdb.com/feature/bestpicture/?ref_=nv_ch_osc
# https://www.imdb.com/search/title/?count=100&groups=oscar_best_picture_winners&sort=year%2Cdesc&ref_=nv_ch_osc
# https://www.imdb.com/event/all/?ref_=nv_ev_all
# https://m.imdb.com/chart/starmeter/?ref_=nv_cel_brn
# https://www.imdb.com/search/name/?gender=male%2Cfemale&ref_=nv_cel_m
# https://help.imdb.com/imdb?ref_=cons_nb_hlp
# ...

# %% [markdown]
# This code will give only links, which are having the attribute("href") value started with "https"(not include "http") in "a" tag.

# %%
for link in soup.find_all("a",  attrs = {'href': re.compile("^https")}):
    print(link['href'])
# Out:
# https://www.imdb.com/calendar/?ref_=nv_mv_cal
# https://www.imdb.com/list/ls016522954/?ref_=nv_tvv_dvd
# https://www.imdb.com/feature/genre/?ref_=nv_ch_gr
# https://m.imdb.com/showtimes/movie/?ref_=nv_mv_sh
# https://www.imdb.com/showtimes/?ref_=nv_mv_sh
# https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth
# https://m.imdb.com/coming-soon/?ref_=nv_mv_cs
# https://www.imdb.com/coming-soon/?ref_=nv_mv_cs
# https://www.imdb.com/whats-on-tv/?ref_=nv_tv_ontv
# https://m.imdb.com/whats-on-tv/?ref_=nv_tv_ontv
# https://www.imdb.com/feature/genre/?ref_=nv_tv_gr
# https://m.imdb.com/feature/bestpicture/?ref_=nv_ch_osc
# https://www.imdb.com/search/title/?count=100&groups=oscar_best_picture_winners&sort=year%2Cdesc&ref_=nv_ch_osc
# https://www.imdb.com/event/all/?ref_=nv_ev_all
# https://m.imdb.com/chart/starmeter/?ref_=nv_cel_brn
# https://www.imdb.com/search/name/?gender=male%2Cfemale&ref_=nv_cel_m
# https://help.imdb.com/imdb?ref_=cons_nb_hlp
# ...

# %% [markdown]
# This code will give only links, which are having the attribute("href") value started with "http://"

# %%
for link in soup.findAll('a', attrs = {"href" : re.compile("^http://")}):
    print(link['href'])
# Out:
# http://www.imdb.com/list/ls000060680/

# %% [markdown]
# This code will give only links, which are having the attribute("href") value started with both "http" and "https" in "a" tag.

# %%
for link in soup.findAll('a', attrs = {"href" : re.compile("^http|https")}):
    print(link['href'])
# Out:
# https://www.imdb.com/calendar/?ref_=nv_mv_cal
# https://www.imdb.com/list/ls016522954/?ref_=nv_tvv_dvd
# https://www.imdb.com/feature/genre/?ref_=nv_ch_gr
# https://m.imdb.com/showtimes/movie/?ref_=nv_mv_sh
# https://www.imdb.com/showtimes/?ref_=nv_mv_sh
# https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth
# https://m.imdb.com/coming-soon/?ref_=nv_mv_cs
# https://www.imdb.com/coming-soon/?ref_=nv_mv_cs
# https://www.imdb.com/whats-on-tv/?ref_=nv_tv_ontv
# https://m.imdb.com/whats-on-tv/?ref_=nv_tv_ontv
# https://www.imdb.com/feature/genre/?ref_=nv_tv_gr
# https://m.imdb.com/feature/bestpicture/?ref_=nv_ch_osc
# https://www.imdb.com/search/title/?count=100&groups=oscar_best_picture_winners&sort=year%2Cdesc&ref_=nv_ch_osc
# https://www.imdb.com/event/all/?ref_=nv_ev_all
# https://m.imdb.com/chart/starmeter/?ref_=nv_cel_brn
# https://www.imdb.com/search/name/?gender=male%2Cfemale&ref_=nv_cel_m
# https://help.imdb.com/imdb?ref_=cons_nb_hlp
# ...

# %% [markdown]
# We can write above code in simple way, this code will also give the only links which are started with both "https" and "http" in "a" tag.

# %%
for link in soup.findAll('a', attrs = {"href" : re.compile("^http")}):
    print(link['href'])
# Out:
# https://www.imdb.com/calendar/?ref_=nv_mv_cal
# https://www.imdb.com/list/ls016522954/?ref_=nv_tvv_dvd
# https://www.imdb.com/feature/genre/?ref_=nv_ch_gr
# https://m.imdb.com/showtimes/movie/?ref_=nv_mv_sh
# https://www.imdb.com/showtimes/?ref_=nv_mv_sh
# https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth
# https://m.imdb.com/coming-soon/?ref_=nv_mv_cs
# https://www.imdb.com/coming-soon/?ref_=nv_mv_cs
# https://www.imdb.com/whats-on-tv/?ref_=nv_tv_ontv
# https://m.imdb.com/whats-on-tv/?ref_=nv_tv_ontv
# https://www.imdb.com/feature/genre/?ref_=nv_tv_gr
# https://m.imdb.com/feature/bestpicture/?ref_=nv_ch_osc
# https://www.imdb.com/search/title/?count=100&groups=oscar_best_picture_winners&sort=year%2Cdesc&ref_=nv_ch_osc
# https://www.imdb.com/event/all/?ref_=nv_ev_all
# https://m.imdb.com/chart/starmeter/?ref_=nv_cel_brn
# https://www.imdb.com/search/name/?gender=male%2Cfemale&ref_=nv_cel_m
# https://help.imdb.com/imdb?ref_=cons_nb_hlp
# ...

# %% [markdown]
# This code will give the all the values of "href" attributes which are in "a" tag, in this output we can see some are not links then also we have got as output because we are extracting all href attribute values.

# %%
for link in soup.findAll('a', href=True):
    print(link['href'])
# Out:
# /?ref_=nv_home
# https://www.imdb.com/calendar/?ref_=nv_mv_cal
# https://www.imdb.com/list/ls016522954/?ref_=nv_tvv_dvd
# /chart/top/?ref_=nv_mv_250
# /chart/moviemeter/?ref_=nv_mv_mpm
# https://www.imdb.com/feature/genre/?ref_=nv_ch_gr
# /chart/boxoffice/?ref_=nv_ch_cht
# https://m.imdb.com/showtimes/movie/?ref_=nv_mv_sh
# https://www.imdb.com/showtimes/?ref_=nv_mv_sh
# https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth
# https://m.imdb.com/coming-soon/?ref_=nv_mv_cs
# https://www.imdb.com/coming-soon/?ref_=nv_mv_cs
# /news/movie/?ref_=nv_nw_mv
# /india/toprated/?ref_=nv_mv_in
# https://www.imdb.com/whats-on-tv/?ref_=nv_tv_ontv
# https://m.imdb.com/whats-on-tv/?ref_=nv_tv_ontv
# /chart/toptv/?ref_=nv_tvv_250
# /chart/tvmeter/?ref_=nv_tvv_mptv
# https://www.imdb.com/feature/genre/?ref_=nv_tv_gr
# /news/tv/?ref_=nv_nw_tv
# /india/tv?ref_=nv_tv_in
# /oscars/?ref_=nv_ev_acd
# https://m.imdb.com/feature/bestpicture/?ref_=nv_ch_osc
# ...

# %% [markdown]
# In above output we got some incompleted links, some cases developers write the short links to make them complete we need to add the page url to that short links.

# %%
for link in soup.findAll('a', href=True):
    if not link['href'].startswith('http'):
        link = url + link['href']
    else:
        link = link['href']
    
    print(link)
# Out:
# https://www.imdb.com/list/ls000060680//?ref_=nv_home
# https://www.imdb.com/calendar/?ref_=nv_mv_cal
# https://www.imdb.com/list/ls016522954/?ref_=nv_tvv_dvd
# https://www.imdb.com/list/ls000060680//chart/top/?ref_=nv_mv_250
# https://www.imdb.com/list/ls000060680//chart/moviemeter/?ref_=nv_mv_mpm
# https://www.imdb.com/feature/genre/?ref_=nv_ch_gr
# https://www.imdb.com/list/ls000060680//chart/boxoffice/?ref_=nv_ch_cht
# https://m.imdb.com/showtimes/movie/?ref_=nv_mv_sh
# https://www.imdb.com/showtimes/?ref_=nv_mv_sh
# https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth
# https://m.imdb.com/coming-soon/?ref_=nv_mv_cs
# https://www.imdb.com/coming-soon/?ref_=nv_mv_cs
# https://www.imdb.com/list/ls000060680//news/movie/?ref_=nv_nw_mv
# https://www.imdb.com/list/ls000060680//india/toprated/?ref_=nv_mv_in
# https://www.imdb.com/whats-on-tv/?ref_=nv_tv_ontv
# https://m.imdb.com/whats-on-tv/?ref_=nv_tv_ontv
# https://www.imdb.com/list/ls000060680//chart/toptv/?ref_=nv_tvv_250
# ...

# %% [markdown]
# Here we are extracting the links from two tags ("a", "link") by passing them as list, where the attribute ("href") value is started with "http" (includes "http" and "https").

# %%
for link in soup.find_all(["a", "link"], attrs = {'href': re.compile("^http")}):
    print(link['href'])
# Out:
# https://www.imdb.com/list/ls000060680/
# https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/favicon_desktop_32x32._CB1582158068_.png
# https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/favicon_iPad_retina_167x167._CB1582158068_.png
# https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/favicon_iPhone_retina_180x180._CB1582158069_.png
# https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/apple-touch-icon-mobile._CB479963088_.png
# https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/apple-touch-icon-mobile-76x76._CB479962152_.png
# https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/apple-touch-icon-mobile-120x120._CB479963088_.png
# https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/apple-touch-icon-web-152x152._CB479963088_.png
# https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/android-mobile-196x196._CB479962153_.png
# https://m.media-amazon.com/images/G/01/imdb/images/imdbsearch-3349468880._CB466670431_.xml
# ...

# %% [markdown]
# Here we are extracting all image links using "src" attribute.

# %%
soup.find_all(class_ = "loadlate")
# Out:
# [<img alt="The Godfather" class="loadlate" data-tconst="tt0068646" height="209" loadlate="https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY209_CR3,0,140,209_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB466725069_.png" width="140"/>,
#  <img alt="The Lord of the Rings: The Return of the King" class="loadlate" data-tconst="tt0167260" height="209" loadlate="https://m.media-amazon.com/images/M/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY209_CR0,0,140,209_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB466725069_.png" width="140"/>,
# ...

# %%
for img in soup.find_all(class_ ="loadlate"):
    print(img['loadlate'])
# Out:
# https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY209_CR3,0,140,209_AL_.jpg
# https://m.media-amazon.com/images/M/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY209_CR0,0,140,209_AL_.jpg
# https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_UY209_CR0,0,140,209_AL_.jpg
# https://m.media-amazon.com/images/M/MV5BN2EyZjM3NzUtNWUzMi00MTgxLWI0NTctMzY4M2VlOTdjZWRiXkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1_UY209_CR0,0,140,209_AL_.jpg
# https://m.media-amazon.com/images/M/MV5BNzQzOTk3OTAtNDQ0Zi00ZTVkLWI0MTEtMDllZjNkYzNjNTc4L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX140_CR0,0,140,209_AL_.jpg
# https://m.media-amazon.com/images/M/MV5BNGE5MzIyNTAtNWFlMC00NDA2LWJiMjItMjc4Yjg1OWM5NzhhXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY209_CR1,0,140,209_AL_.jpg
# ...

# %%
for i in soup.find_all('a'):
    print(i.text.strip())
# Out:
# Release Calendar
# DVD & Blu-ray Releases
# Top Rated Movies
# Most Popular Movies
# Browse Movies by Genre
# Top Box Office
# Showtimes & Tickets
# Showtimes & Tickets
# In Theaters
# Coming Soon
# Coming Soon
# Movie News
# India Movie Spotlight
# What's on TV & Streaming
# What's on TV & Streaming
# Top Rated Shows
# Most Popular Shows
# Browse TV Shows by Genre
# TV News
# India TV Spotlight
# Oscars
# Best Picture Winners
# Best Picture Winners
# Golden Globes
# Emmys
# San Diego Comic-Con
# New York Comic-Con
# Sundance Film Festival
# Toronto Int'l Film Festival
# Awards Central
# Festival Central
# All Events
# Born Today
# Most Popular Celebs
# Most Popular Celebs
# Celebrity News
# IMDb Originals
# Latest Trailers
# Help Center
# Contributor Zone
# Polls
# For Industry Professionals
#
# All
# Titles
# TV Episodes
# Celebs
# Companies
# Keywords
# Advanced Search
#
# Watchlist
# Sign In
# Copy from this list
# Export
# Report this list
# colm-hearne365
# »
# Reset
# »
#
# ...

# %%
soup.findAll('a', attrs = {"href" : re.compile("^/title")})
# Out:
# [<a href="/title/tt0068646/"> <img alt="The Godfather" class="loadlate" data-tconst="tt0068646" height="209" loadlate="https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY209_CR3,0,140,209_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB466725069_.png" width="140"/>
#  </a>,
#  <a href="/title/tt0068646/">The Godfather</a>,
#  <a href="/title/tt0167260/"> <img alt="The Lord of the Rings: The Return of the King" class="loadlate" data-tconst="tt0167260" height="209" loadlate="https://m.media-amazon.com/images/M/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY209_CR0,0,140,209_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB466725069_.png" width="140"/>
#  </a>,
#  <a href="/title/tt0167260/">The Lord of the Rings: The Return of the King</a>,
# ...

# %%
soup.findAll('a', attrs = {"href" : re.compile("^/title")})
# Out:
# [<a href="/title/tt0068646/"> <img alt="The Godfather" class="loadlate" data-tconst="tt0068646" height="209" loadlate="https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY209_CR3,0,140,209_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB466725069_.png" width="140"/>
#  </a>,
#  <a href="/title/tt0068646/">The Godfather</a>,
#  <a href="/title/tt0167260/"> <img alt="The Lord of the Rings: The Return of the King" class="loadlate" data-tconst="tt0167260" height="209" loadlate="https://m.media-amazon.com/images/M/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY209_CR0,0,140,209_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB466725069_.png" width="140"/>
#  </a>,
#  <a href="/title/tt0167260/">The Lord of the Rings: The Return of the King</a>,
# ...

# %%
movie=[]
for link in soup.findAll('a', attrs = {"href" : re.compile("^/title")}):
    movie.append(link.text.strip())

# %%
len(movie)
# Out:
# 201

# %%
movie=[]
for link in soup.findAll('a', attrs = {"href" : re.compile("^/title")}):
    if len(link.text.strip())!=0:
        movie.append(link.text.strip())

# %%
movie = []
for x in soup.find_all('h3'):
    for y in x.find_all('a'):
        movie.append(y.text.strip())

# %%
len(movie)
# Out:
# 100

# %%
movie
# Out:
# ['The Godfather',
#  'The Lord of the Rings: The Return of the King',
#  'Inception',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Matrix',
#  'The Lord of the Rings: The Two Towers',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'Léon',
#  'Gladiator',
#  'Terminator 2: Judgment Day',
#  'Avengers: Endgame',
#  'Braveheart',
#  'Toy Story',
#  'Aliens',
#  'Batman Begins',
#  'Indiana Jones and the Last Crusade',
#  'The Avengers',
#  'Beauty and the Beast',
#  'The Sound of Music',
#  'Iron Man',
#  'Star Trek',
#  'Avatar',
#  'Titanic',
#  'Lost in Translation',
#  'Home Alone',
#  'Batman',
#  'King Kong',
#  'The Shawshank Redemption',
#  'The Godfather: Part II',
#  'Pulp Fiction',
#  "Schindler's List",
#  'Forrest Gump',
#  "One Flew Over the Cuckoo's Nest",
#  'Star Wars',
#  "It's a Wonderful Life",
#  'The Prestige',
#  'Back to the Future',
#  'The Lion King',
#  'Avengers: Infinity War',
#  'Psycho',
#  'Casablanca',
#  'City Lights',
# ...

# %%
year= []
for i in soup.find_all(class_ = "lister-item-year text-muted unbold"):
    year.append(i.text)

# %%
year
# Out:
# ['(1972)',
#  '(2003)',
#  '(2010)',
#  '(2001)',
#  '(1999)',
#  '(2002)',
#  '(1980)',
#  '(1994)',
#  '(2000)',
#  '(1991)',
#  '(2019)',
#  '(1995)',
#  '(1995)',
#  '(1986)',
#  '(2005)',
#  '(1989)',
#  '(2012)',
#  '(1991)',
#  '(1965)',
#  '(2008)',
#  '(2009)',
#  '(2009)',
#  '(1997)',
#  '(2003)',
#  '(1990)',
#  '(1989)',
#  '(2005)',
#  '(1994)',
#  '(1974)',
#  '(1994)',
#  '(1993)',
#  '(1994)',
#  '(1975)',
#  '(1977)',
#  '(1946)',
#  '(2006)',
#  '(1985)',
#  '(1994)',
#  '(2018)',
#  '(1960)',
#  '(1942)',
#  '(1931)',
#  '(2012)',
#  '(2012)',
#  '(2008)',
#  '(1981)',
#  '(1954)',
#  '(I) (2017)',
#  '(1983)',
#  '(2010)',
#  '(1987)',
#  '(1959)',
#  '(1952)',
#  '(1921)',
#  '(2009)',
#  '(2001)',
#  '(1988)',
#  '(I) (2015)',
#  '(1925)',
#  '(1998)',
#  '(2015)',
#  '(1993)',
#  '(2016)',
#  '(1989)',
#  '(1954)',
#  '(1939)',
#  '(1962)',
#  '(2001)',
#  '(1984)',
#  '(2007)',
#  '(2007)',
#  '(1975)',
#  '(1988)',
#  '(1999)',
#  '(1974)',
#  '(1951)',
# ...

# %%
len(year)
# Out:
# 100

# %%
import pandas as pd
demo = pd.DataFrame()
demo['name'] = movie
demo['year'] = year
demo
# Out:
#                                                  name    year
# 0                                       The Godfather  (1972)
# 1       The Lord of the Rings: The Return of the King  (2003)
# 2                                           Inception  (2010)
# 3   The Lord of the Rings: The Fellowship of the Ring  (2001)
# 4                                          The Matrix  (1999)
# ..                                                ...     ...
# 95                               The Greatest Showman  (2017)
# 96                                    The Jungle Book  (1967)
# 97                                         Robin Hood  (1973)
# 98                                      Kung Fu Panda  (2008)
# 99                                             Looper  (2012)
#
# [100 rows x 2 columns]
